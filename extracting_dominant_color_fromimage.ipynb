# %%
from colorthief import ColorThief
import matplotlib.pyplot as plt

# %%
img = "/Users/krrishjuneja/Desktop/python/projects/dog.jpg"
cl=ColorThief(img)
prominent_color=cl.get_color(quality=1)

# %%
prominent_color
# Out:
# (76, 97, 37)

# %%
from webcolors import rgb_to_name
rgb_values=prominent_color

# %%
import numpy as np


# Create an image with a single pixel of the specified color
image = np.array([[prominent_color]])

# Display the image
plt.imshow(image)
plt.show()
